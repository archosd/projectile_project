# %%
from projectile_package.projectile import flying_mass
from projectile_package.projectile_plot import plot_xy

# %%
t, x, y, vx, vy = flying_mass(10., 10., mass=1., k=0.035,dt =0.1)

print(t)
# Out:
# [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999, 1.0999999999999999, 1.2]

# %%
plot_xy(x, y)
